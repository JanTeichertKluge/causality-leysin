# %%
import pandas as pd

pd.read_csv("SeriesReport-20260821045422_221c9b.csv")
# Out:
#      Year Period  labor force  employment  unemployment  unemployment rate  \
# 0    2012    Jan       287972      259343         28629                9.9
# 1    2012    Feb       288569      261026         27543                9.5
# 2    2012    Mar       290339      263409         26930                9.3
# 3    2012    Apr       289730      264146         25584                8.8
# 4    2012    May       290885      264390         26495                9.1
# ..    ...    ...          ...         ...           ...                ...
# 127  2022    Aug       362418      350818         11600                3.2
# 128  2022    Sep       365085      354136         10949                3.0
# 129  2022    Oct       358306      341506         16800                4.7
# 130  2022    Nov       360374      345365         15009                4.2
# 131  2022    Dec       362283      349850         12433                3.4
#
#      event_time
# 0           -68
# 1           -67
# ...
